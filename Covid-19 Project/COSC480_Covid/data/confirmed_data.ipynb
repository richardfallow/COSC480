# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('confirmed.csv')
df.head()
# Out:
#   Date notified of potential case     Sex Age group         DHB  \
# 0                      07/05/2020  Female  20 to 29   Waitematā
# 1                      06/05/2020    Male    5 to 9     Waikato
# 2                      05/05/2020  Female  10 to 14   Waitematā
# 3                      01/05/2020    Male  60 to 69    Auckland
# 4                      01/05/2020  Female  20 to 29  Canterbury
#
#   Overseas travel Last country before return Flight number  \
# 0              No                        NaN           NaN
# 1              No                        NaN           NaN
# 2              No                        NaN           NaN
# 3              No                        NaN           NaN
# 4              No                        NaN           NaN
#
#   Flight departure date Arrival date
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4                   NaN          NaN

# %%
df.shape
# Out:
# (1142, 9)

# %%
df.dtypes
# Out:
# Date notified of potential case    object
# Sex                                object
# Age group                          object
# DHB                                object
# Overseas travel                    object
# Last country before return         object
# Flight number                      object
# Flight departure date              object
# Arrival date                       object
# dtype: object

# %%
df['date'] =pd.to_datetime(df['Date notified of potential case'])

# %%
df.dtypes
# Out:
# Date notified of potential case    datetime64[ns]
# Sex                                        object
# Age group                                  object
# DHB                                        object
# Overseas travel                            object
# Last country before return                 object
# Flight number                              object
# Flight departure date                      object
# Arrival date                               object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1142 entries, 0 to 1141
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date notified of potential case  1142 non-null   datetime64[ns]
#  1   Sex                              1141 non-null   object
#  2   Age group                        1142 non-null   object
#  3   DHB                              1142 non-null   object
#  4   Overseas travel                  1142 non-null   object
#  5   Last country before return       502 non-null    object
#  6   Flight number                    437 non-null    object
#  7   Flight departure date            417 non-null    object
#  8   Arrival date                     511 non-null    object
# dtypes: datetime64[ns](1), object(8)
# memory usage: 80.4+ KB

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1137    False
# 1138    False
# 1139    False
# 1140    False
# 1141    False
# Length: 1142, dtype: bool

# %%
# Remove all duplicates

# %%
df['DHB'].value_counts()
# Out:
# Southern              186
# Waitematā             161
# Waikato               153
# Auckland              126
# Counties Manukau      105
# Canterbury             98
# Capital and Coast      71
# Hawke's Bay            38
# Nelson Marlborough     37
# Bay of Plenty          33
# Northland              26
# MidCentral             26
# Hutt Valley            17
# South Canterbury       15
# Lakes                  15
# Taranaki               14
# Whanganui               8
# Wairarapa               6
# West Coast              4
# Tairāwhiti              3
# Name: DHB, dtype: int64

# %%
topPub =df['DHB'].value_counts().plot(kind='bar',figsize=(40,8))

# %%
top10 = df["DHB"].value_counts()
top10.sort_values(ascending=False)
top10 = top10[:10]
top10.plot(kind="bar")

# %%
age = df['Age group'].value_counts()
age.plot(kind='pie',figsize=(8,8))

# %%
# Need to adjust pie chart

# %%
top10 = df["Last country before return"].value_counts()
top10.sort_values(ascending=False)
top10 = top10[:10]
top10.plot(kind="bar")

# %%
df['Sex'].value_counts()
# Out:
# Female    612
# Male      529
# Name: Sex, dtype: int64

# %%
pie_values = df['Sex'].value_counts()
pie_values.plot(kind="pie",figsize=(8,8))

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined
