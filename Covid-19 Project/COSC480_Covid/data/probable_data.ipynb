# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('probable.csv')
df.head()
# Out:
#   Date notified of potential case     Sex Age group        DHB  \
# 0                      08/05/2020  Female  40 to 49  Waitematā
# 1                      05/05/2020    Male  40 to 49   Auckland
# 2                      01/05/2020  Female  20 to 29   Auckland
# 3                      01/05/2020    Male  30 to 39  Waitematā
# 4                      26/04/2020  Female  50 to 59   Taranaki
#
#   Overseas travel Last country before return Flight number  \
# 0              No                        NaN           NaN
# 1              No                        NaN           NaN
# 2              No                        NaN           NaN
# 3              No                        NaN           NaN
# 4              No                        NaN           NaN
#
#   Flight departure date Arrival date
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4                   NaN          NaN

# %%
df.shape
# Out:
# (350, 9)

# %%
df.dtypes
# Out:
# Date notified of potential case    object
# Sex                                object
# Age group                          object
# DHB                                object
# Overseas travel                    object
# Last country before return         object
# Flight number                      object
# Flight departure date              object
# Arrival date                       object
# dtype: object

# %%
df['Date notified of potential case'] =pd.to_datetime(df['Date notified of potential case'])

# %%
df.dtypes
# Out:
# Date notified of potential case    datetime64[ns]
# Sex                                        object
# Age group                                  object
# DHB                                        object
# Overseas travel                            object
# Last country before return                 object
# Flight number                              object
# Flight departure date                      object
# Arrival date                               object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date notified of potential case  350 non-null    datetime64[ns]
#  1   Sex                              350 non-null    object
#  2   Age group                        350 non-null    object
#  3   DHB                              350 non-null    object
#  4   Overseas travel                  350 non-null    object
#  5   Last country before return       54 non-null     object
#  6   Flight number                    36 non-null     object
#  7   Flight departure date            35 non-null     object
#  8   Arrival date                     54 non-null     object
# dtypes: datetime64[ns](1), object(8)
# memory usage: 24.7+ KB

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 345    False
# 346    False
# 347    False
# 348    False
# 349    False
# Length: 350, dtype: bool

# %%
# Remove all duplicates

# %%
df['DHB'].value_counts()
# Out:
# Waitematā             71
# Canterbury            65
# Auckland              52
# Waikato               34
# Southern              30
# Capital and Coast     24
# Counties Manukau      22
# Bay of Plenty         14
# Nelson Marlborough    12
# Hawke's Bay            6
# MidCentral             5
# Hutt Valley            3
# South Canterbury       2
# Taranaki               2
# Wairarapa              2
# Northland              2
# Tairāwhiti             1
# Whanganui              1
# West Coast             1
# Lakes                  1
# Name: DHB, dtype: int64

# %%
topPub =df['DHB'].value_counts().plot(kind='bar',figsize=(40,8))

# %%
top10 = df["DHB"].value_counts()
top10.sort_values(ascending=False)
top10 = top10[:10]
top10.plot(kind="bar")

# %%
age = df['Age group'].value_counts()
age.plot(kind='pie',figsize=(8,8))

# %%
# Need to adjust pie chart

# %%
top10 = df["Last country before return"].value_counts()
top10.sort_values(ascending=False)
top10 = top10[:10]
top10.plot(kind="bar")

# %%
df['Sex'].value_counts()
# Out:
# Female    216
# Male      134
# Name: Sex, dtype: int64

# %%
pie_values = df['Sex'].value_counts()
pie_values.plot(kind="pie",figsize=(8,8))
